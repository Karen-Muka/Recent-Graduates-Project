# %% [markdown]
# Assignment 7

# %% [markdown]
# Using the recent-grads.csv dataset, answer all the questions .
#
# 1 a.Display the data for those who have taken Psychology & Social Work as their major category .
#
# b. Show the share of women graduates above 0.5 who have taken Psychology & Social Work as their major category.
#
# 2.Create a Data Frame showing the number of graduates of Chemical Engineering with Full time year round employment.
#
# 3.Output a subset consisting of graduates of Psychology & Social Work and show their respective employment status,i.e. : those employed,part-time employment,full time employment & those without jobs.
#
# 4.Use loc & iloc methods to display the rows 21-25 and the last three columns of this dataset.

# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\KMuka.CRAKENYA\Downloads\recent-grads.csv')
df
# Out:
#      Rank  Major_code                                      Major    Total  \
# 0       1        2419                      PETROLEUM ENGINEERING   2339.0
# 1       2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2       3        2415                  METALLURGICAL ENGINEERING    856.0
# 3       4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4       5        2405                       CHEMICAL ENGINEERING  32260.0
# ..    ...         ...                                        ...      ...
# 168   169        3609                                    ZOOLOGY   8409.0
# 169   170        5201                     EDUCATIONAL PSYCHOLOGY   2854.0
# 170   171        5202                        CLINICAL PSYCHOLOGY   2838.0
# 171   172        5203                      COUNSELING PSYCHOLOGY   4626.0
# 172   173        3501                            LIBRARY SCIENCE   1098.0
#
#          Men    Women            Major_category  ShareWomen  Sample_size  \
# 0     2057.0    282.0               Engineering    0.120564           36
# 1      679.0     77.0               Engineering    0.101852            7
# 2      725.0    131.0               Engineering    0.153037            3
# 3     1123.0    135.0               Engineering    0.107313           16
# 4    21239.0  11021.0               Engineering    0.341631          289
# ..       ...      ...                       ...         ...          ...
# 168   3050.0   5359.0    Biology & Life Science    0.637293           47
# 169    522.0   2332.0  Psychology & Social Work    0.817099            7
# 170    568.0   2270.0  Psychology & Social Work    0.799859           13
# 171    931.0   3695.0  Psychology & Social Work    0.798746           21
# 172    134.0    964.0                 Education    0.877960            2
#
#      Employed  ...  Part_time  Full_time_year_round  Unemployed  \
# 0        1976  ...        270                  1207          37
# 1         640  ...        170                   388          85
# 2         648  ...        133                   340          16
# 3         758  ...        150                   692          40
# 4       25694  ...       5180                 16697        1672
# ..        ...  ...        ...                   ...         ...
# 168      6259  ...       2190                  3602         304
# 169      2125  ...        572                  1211         148
# 170      2101  ...        648                  1293         368
# 171      3777  ...        965                  2738         214
# 172       742  ...        237                   410          87
#
#      Unemployment_rate  Median  P25th   P75th  College_jobs  Non_college_jobs  \
# 0             0.018381  110000  95000  125000          1534               364
# 1             0.117241   75000  55000   90000           350               257
# 2             0.024096   73000  50000  105000           456               176
# 3             0.050125   70000  43000   80000           529               102
# 4             0.061098   65000  50000   75000         18314              4440
# ..                 ...     ...    ...     ...           ...               ...
# 168           0.046320   26000  20000   39000          2771              2947
# 169           0.065112   25000  24000   34000          1488               615
# 170           0.149048   25000  25000   40000           986               870
# 171           0.053621   23400  19200   26000          2403              1245
# 172           0.104946   22000  20000   22000           288               338
#
#      Low_wage_jobs
# 0              193
# 1               50
# 2                0
# 3                0
# 4              972
# ..             ...
# 168            743
# 169             82
# 170            622
# 171            308
# 172            192
#
# [173 rows x 21 columns]

# %% [markdown]
# 1 a.Display the data for those who have taken Psychology & Social Work as their major category

# %%
Psychology_SocialWork = df[df['Major_category'] == 'Psychology & Social Work']
Psychology_SocialWork
# Out:
#      Rank  Major_code                                      Major     Total  \
# 70     71        5205   INDUSTRIAL AND ORGANIZATIONAL PSYCHOLOGY    3014.0
# 91     92        5206                          SOCIAL PSYCHOLOGY    1386.0
# 145   146        5200                                 PSYCHOLOGY  393735.0
# 151   152        5404                                SOCIAL WORK   53552.0
# 155   156        5299                   MISCELLANEOUS PSYCHOLOGY    9628.0
# 156   157        5403  HUMAN SERVICES AND COMMUNITY ORGANIZATION    9374.0
# 169   170        5201                     EDUCATIONAL PSYCHOLOGY    2854.0
# 170   171        5202                        CLINICAL PSYCHOLOGY    2838.0
# 171   172        5203                      COUNSELING PSYCHOLOGY    4626.0
#
#          Men     Women            Major_category  ShareWomen  Sample_size  \
# 70    1075.0    1939.0  Psychology & Social Work    0.643331           24
# 91     413.0     973.0  Psychology & Social Work    0.702020            8
# 145  86648.0  307087.0  Psychology & Social Work    0.779933         2584
# 151   5137.0   48415.0  Psychology & Social Work    0.904075          374
# 155   1936.0    7692.0  Psychology & Social Work    0.798920           60
# 156    885.0    8489.0  Psychology & Social Work    0.905590           89
# 169    522.0    2332.0  Psychology & Social Work    0.817099            7
# 170    568.0    2270.0  Psychology & Social Work    0.799859           13
# 171    931.0    3695.0  Psychology & Social Work    0.798746           21
#
#      Employed  ...  Part_time  Full_time_year_round  Unemployed  \
# 70       2343  ...       1095                  1409         286
# 91       1080  ...        433                   529          33
# 145    307933  ...     115172                174438       28169
# 151     45038  ...      13481                 27588        3329
# 155      7653  ...       3221                  3838         419
# 156      8294  ...       2405                  5061         326
# 169      2125  ...        572                  1211         148
# 170      2101  ...        648                  1293         368
# 171      3777  ...        965                  2738         214
#
#      Unemployment_rate  Median  P25th  P75th  College_jobs  Non_college_jobs  \
# 70            0.108787   40000  32000  53000           559              1224
# 91            0.029650   36000  34000  45000           434               593
# 145           0.083811   31500  24000  41000        125148            141860
# 151           0.068828   30000  25000  35000         27449             14416
# 155           0.051908   30000  20800  40000          2960              3948
# 156           0.037819   30000  24000  35000          2878              4595
# 169           0.065112   25000  24000  34000          1488               615
# 170           0.149048   25000  25000  40000           986               870
# 171           0.053621   23400  19200  26000          2403              1245
#
#      Low_wage_jobs
# 70             272
# 91              37
# 145          48207
# 151           4344
# 155           1650
# 156            724
# 169             82
# 170            622
# 171            308
#
# [9 rows x 21 columns]

# %% [markdown]
# 1b. Show the share of women graduates above 0.5 who have taken Psychology & Social Work as their major category

# %%
filter_criteria = (df['Major_category'] == 'Psychology & Social Work') & (df['ShareWomen'] >=.5)
filter_criteria
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 168    False
# 169     True
# 170     True
# 171     True
# 172    False
# Length: 173, dtype: bool

# %%
df_fc = df[filter_criteria]
df_fc
# Out:
#      Rank  Major_code                                      Major     Total  \
# 70     71        5205   INDUSTRIAL AND ORGANIZATIONAL PSYCHOLOGY    3014.0
# 91     92        5206                          SOCIAL PSYCHOLOGY    1386.0
# 145   146        5200                                 PSYCHOLOGY  393735.0
# 151   152        5404                                SOCIAL WORK   53552.0
# 155   156        5299                   MISCELLANEOUS PSYCHOLOGY    9628.0
# 156   157        5403  HUMAN SERVICES AND COMMUNITY ORGANIZATION    9374.0
# 169   170        5201                     EDUCATIONAL PSYCHOLOGY    2854.0
# 170   171        5202                        CLINICAL PSYCHOLOGY    2838.0
# 171   172        5203                      COUNSELING PSYCHOLOGY    4626.0
#
#          Men     Women            Major_category  ShareWomen  Sample_size  \
# 70    1075.0    1939.0  Psychology & Social Work    0.643331           24
# 91     413.0     973.0  Psychology & Social Work    0.702020            8
# 145  86648.0  307087.0  Psychology & Social Work    0.779933         2584
# 151   5137.0   48415.0  Psychology & Social Work    0.904075          374
# 155   1936.0    7692.0  Psychology & Social Work    0.798920           60
# 156    885.0    8489.0  Psychology & Social Work    0.905590           89
# 169    522.0    2332.0  Psychology & Social Work    0.817099            7
# 170    568.0    2270.0  Psychology & Social Work    0.799859           13
# 171    931.0    3695.0  Psychology & Social Work    0.798746           21
#
#      Employed  ...  Part_time  Full_time_year_round  Unemployed  \
# 70       2343  ...       1095                  1409         286
# 91       1080  ...        433                   529          33
# 145    307933  ...     115172                174438       28169
# 151     45038  ...      13481                 27588        3329
# 155      7653  ...       3221                  3838         419
# 156      8294  ...       2405                  5061         326
# 169      2125  ...        572                  1211         148
# 170      2101  ...        648                  1293         368
# 171      3777  ...        965                  2738         214
#
#      Unemployment_rate  Median  P25th  P75th  College_jobs  Non_college_jobs  \
# 70            0.108787   40000  32000  53000           559              1224
# 91            0.029650   36000  34000  45000           434               593
# 145           0.083811   31500  24000  41000        125148            141860
# 151           0.068828   30000  25000  35000         27449             14416
# 155           0.051908   30000  20800  40000          2960              3948
# 156           0.037819   30000  24000  35000          2878              4595
# 169           0.065112   25000  24000  34000          1488               615
# 170           0.149048   25000  25000  40000           986               870
# 171           0.053621   23400  19200  26000          2403              1245
#
#      Low_wage_jobs
# 70             272
# 91              37
# 145          48207
# 151           4344
# 155           1650
# 156            724
# 169             82
# 170            622
# 171            308
#
# [9 rows x 21 columns]

# %% [markdown]
# 2.Create a Data Frame showing the number of graduates of Chemical Engineering with Full time year round employment

# %%
filter_criteria = (df['Major'] == 'CHEMICAL ENGINEERING') & (df['Full_time_year_round'])
filter_criteria
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 168    False
# 169    False
# 170    False
# 171    False
# 172    False
# Length: 173, dtype: bool

# %%
df2_fc = df[filter_criteria]
df2_fc
# Out:
#    Rank  Major_code                 Major    Total      Men    Women  \
# 4     5        2405  CHEMICAL ENGINEERING  32260.0  21239.0  11021.0
#
#   Major_category  ShareWomen  Sample_size  Employed  ...  Part_time  \
# 4    Engineering    0.341631          289     25694  ...       5180
#
#    Full_time_year_round  Unemployed  Unemployment_rate  Median  P25th  P75th  \
# 4                 16697        1672           0.061098   65000  50000  75000
#
#    College_jobs  Non_college_jobs  Low_wage_jobs
# 4         18314              4440            972
#
# [1 rows x 21 columns]

# %% [markdown]
# 3.Output a subset consisting of graduates of Psychology & Social Work and show their respective employment status,i.e. : those employed,part-time employment,full time employment & those without jobs

# %%
filter_criteria = (df['Major_category'] == 'Psychology & Social Work') & (df['Employed']) & (df['Part_time']) & (df['Full_time_year_round']) & (df['Unemployed'])
filter_criteria
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 168    False
# 169    False
# 170    False
# 171    False
# 172    False
# Length: 173, dtype: bool

# %%
df_fc=df[filter_criteria]
df
# Out:
#      Rank  Major_code                                      Major    Total  \
# 0       1        2419                      PETROLEUM ENGINEERING   2339.0
# 1       2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2       3        2415                  METALLURGICAL ENGINEERING    856.0
# 3       4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4       5        2405                       CHEMICAL ENGINEERING  32260.0
# ..    ...         ...                                        ...      ...
# 168   169        3609                                    ZOOLOGY   8409.0
# 169   170        5201                     EDUCATIONAL PSYCHOLOGY   2854.0
# 170   171        5202                        CLINICAL PSYCHOLOGY   2838.0
# 171   172        5203                      COUNSELING PSYCHOLOGY   4626.0
# 172   173        3501                            LIBRARY SCIENCE   1098.0
#
#          Men    Women            Major_category  ShareWomen  Sample_size  \
# 0     2057.0    282.0               Engineering    0.120564           36
# 1      679.0     77.0               Engineering    0.101852            7
# 2      725.0    131.0               Engineering    0.153037            3
# 3     1123.0    135.0               Engineering    0.107313           16
# 4    21239.0  11021.0               Engineering    0.341631          289
# ..       ...      ...                       ...         ...          ...
# 168   3050.0   5359.0    Biology & Life Science    0.637293           47
# 169    522.0   2332.0  Psychology & Social Work    0.817099            7
# 170    568.0   2270.0  Psychology & Social Work    0.799859           13
# 171    931.0   3695.0  Psychology & Social Work    0.798746           21
# 172    134.0    964.0                 Education    0.877960            2
#
#      Employed  ...  Part_time  Full_time_year_round  Unemployed  \
# 0        1976  ...        270                  1207          37
# 1         640  ...        170                   388          85
# 2         648  ...        133                   340          16
# 3         758  ...        150                   692          40
# 4       25694  ...       5180                 16697        1672
# ..        ...  ...        ...                   ...         ...
# 168      6259  ...       2190                  3602         304
# 169      2125  ...        572                  1211         148
# 170      2101  ...        648                  1293         368
# 171      3777  ...        965                  2738         214
# 172       742  ...        237                   410          87
#
#      Unemployment_rate  Median  P25th   P75th  College_jobs  Non_college_jobs  \
# 0             0.018381  110000  95000  125000          1534               364
# 1             0.117241   75000  55000   90000           350               257
# 2             0.024096   73000  50000  105000           456               176
# 3             0.050125   70000  43000   80000           529               102
# 4             0.061098   65000  50000   75000         18314              4440
# ..                 ...     ...    ...     ...           ...               ...
# 168           0.046320   26000  20000   39000          2771              2947
# 169           0.065112   25000  24000   34000          1488               615
# 170           0.149048   25000  25000   40000           986               870
# 171           0.053621   23400  19200   26000          2403              1245
# 172           0.104946   22000  20000   22000           288               338
#
#      Low_wage_jobs
# 0              193
# 1               50
# 2                0
# 3                0
# 4              972
# ..             ...
# 168            743
# 169             82
# 170            622
# 171            308
# 172            192
#
# [173 rows x 21 columns]

# %% [markdown]
# 4.Use loc & iloc methods to display the rows 21-25 and the last three columns of this dataset.

# %%
rows = [21, 22, 23, 24, 25]
cols = ['College_jobs', 'Non_college_jobs', 'Low_wage_jobs']

df.loc[rows, cols]
# Out:
#     College_jobs  Non_college_jobs  Low_wage_jobs
# 21          1183              1274            485
# 22          5126              2686            696
# 23          1911               305             70
# 24          6342              5741            708
# 25         28526              9356           2899

# %%
df.iloc[21:26,-3:]
# Out:
#     College_jobs  Non_college_jobs  Low_wage_jobs
# 21          1183              1274            485
# 22          5126              2686            696
# 23          1911               305             70
# 24          6342              5741            708
# 25         28526              9356           2899
